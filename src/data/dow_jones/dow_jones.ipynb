# %%
# %cd ../..
# Out:
# c:\Boyko Boev\Stock-Market-Prediction\src
# c:\Boyko Boev\Stock-Market-Prediction\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from data.dow_jones.dow_jones import get_dow_jones_data, download_dow_jones_data
from utils.chart import config_chart, plot_chart_line

# %%
start_date = "1995-10-01"
end_date = "2024-02-01"

# download_dow_jones_data()
# Out:
# c:\Boyko Boev\Stock-Market-Prediction\venv\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ### View csv data

# %%
data = get_dow_jones_data(start_date, end_date)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#            Date         Open         High          Low        Close  \
# 948  1995-10-02  4789.799805  4789.799805  4761.259766  4761.259766
# 949  1995-10-03  4763.100098  4767.399902  4716.100098  4749.700195
# 950  1995-10-04  4749.299805  4749.700195  4726.939941  4740.669922
# 951  1995-10-05  4740.000000  4762.709961  4735.250000  4762.709961
# 952  1995-10-06  4762.399902  4783.660156  4749.700195  4769.209961
#
#        Adj Close    Volume
# 948  4761.259766  29050000
# 949  4749.700195  32970000
# 950  4740.669922  33080000
# 951  4762.709961  32630000
# 952  4769.209961  25080000

# %%
data.shape
# Out:
# (7133, 7)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
plt = plot_chart_line(
    data=data['Close'],
    label='Nasdaq Close Price',
    title='Nasdaq Daily Close Price'
)
