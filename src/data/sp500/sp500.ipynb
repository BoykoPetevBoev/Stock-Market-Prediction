# %%
# %cd ../..
# Out:
# f:\DR\Stock-Market-Prediction\src
# f:\DR\Stock-Market-Prediction\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from data.sp500.sp500 import get_SP500_data
from utils.chart import plot_chart_line

# %%
start_date = "2000-01-01"
end_date = "2024-02-01"

# download_SP500_data(start_date, end_date)

# %% [markdown]
# ### View csv data

# %%
data = get_SP500_data(start_date, end_date)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971
# 1  2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044
# 2  2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985
# 3  2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951
# 4  2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971
#
#      Adj Close      Volume     Change
# 0  1455.219971   931800000 -14.030029
# 1  1399.420044  1009000000 -55.799927
# 2  1402.109985  1085500000   2.689941
# 3  1403.449951  1092300000   1.339966
# 4  1441.469971  1225200000  38.020020

# %%
data.shape
# Out:
# (6058, 8)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'Change'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# Change       float64
# dtype: object

# %% [markdown]
# ### Plot csv data

# %%
plt = plot_chart_line(
    data=data['Close'],
    label='S&P500 Close Price',
    title='S&P500 Daily Close Price'
)

# %%
plt = plot_chart_line(
    data=data['Change'],
    label='S&P500 Price Change',
    title='S&P500 Daily Change Price'
)
