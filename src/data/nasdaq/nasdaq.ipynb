# %%
# %cd ../..
# Out:
# c:\Boyko Boev\Stock-Market-Prediction\src

# %%
from data.nasdaq.nasdaq import get_nasdaq_data, download_nasdaq_data
from utils.chart import config_chart, plot_chart_line

# %%
start_date = "1995-10-01"
end_date = "2024-02-01"

# download_nasdaq_data()

# %% [markdown]
# ### View csv data

# %%
data = get_nasdaq_data(start_date, end_date)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2529  1995-10-02  585.080017  587.900024  573.169983  573.869995  573.869995
# 2530  1995-10-03  573.869995  575.809998  563.950012  573.159973  573.159973
# 2531  1995-10-04  573.159973  573.159973  557.429993  558.989990  558.989990
# 2532  1995-10-05  558.989990  572.760010  556.609985  572.750000  572.750000
# 2533  1995-10-06  572.750000  581.739990  566.979980  567.419983  567.419983
#
#          Volume
# 2529  393760000
# 2530  456000000
# 2531  386390000
# 2532  456560000
# 2533  450010000

# %%
data.shape
# Out:
# (7133, 7)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
plt = plot_chart_line(
    data=data['Close'],
    label='Nasdaq Close Price',
    title='Nasdaq Daily Close Price'
)
