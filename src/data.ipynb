# %%
# %cd ..

# %%
from constants import SP500_TICKER, DJI_TICKER, NASDAQ_TICKER, GOLD_TICKER
from utils.chart import plot_chart_line, config_chart
from data.data import get_data

# %% [markdown]
# ---

# %% [markdown]
# ## S&P 500

# %%
data = get_data(SP500_TICKER)
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-05-24  1373.859985  1401.750000  1361.089966  1399.050049  1399.050049
# 2000-05-25  1399.050049  1411.650024  1373.930054  1381.520020  1381.520020
# 2000-05-26  1381.520020  1391.420044  1369.750000  1378.020020  1378.020020
# 2000-05-30  1378.020020  1422.449951  1378.020020  1422.449951  1422.449951
# 2000-05-31  1422.439941  1434.489990  1415.500000  1420.599976  1420.599976
# ...                 ...          ...          ...          ...          ...
# 2024-01-25  4886.660156  4898.149902  4869.339844  4894.160156  4894.160156
# 2024-01-26  4888.910156  4906.689941  4881.470215  4890.970215  4890.970215
# 2024-01-29  4892.950195  4929.310059  4887.399902  4927.930176  4927.930176
# 2024-01-30  4925.890137  4931.089844  4916.270020  4924.970215  4924.970215
# 2024-01-31  4899.189941  4906.750000  4845.149902  4845.649902  4845.649902
#
# ...

# %%
index = 500

plt = config_chart('Daily Change')
plt.plot(data.Change[0:index])

plt = config_chart('Original Data')
plt.plot(data.Close[0:index])

plt = config_chart('Moving Average')
plt.plot(data.MA10[0:index])
plt.plot(data.MA20[0:index])
plt.plot(data.MA50[0:index])
plt.plot(data.MA100[0:index])

plt = config_chart('RSI')
plt.plot(data.RSI[0:index])

plt = config_chart('Stoch')
plt.plot(data.Stochastic_K[0:index])
plt.plot(data.Stochastic_D[0:index])

# %% [markdown]
# ---

# %% [markdown]
# ## Nasdaq

# %%
data = get_data(NASDAQ_TICKER)
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 1996-02-22    627.280029    644.210022    627.280029    643.409973
# 1996-02-23    643.409973    647.340027    634.599976    642.590027
# 1996-02-26    642.590027    645.239990    636.559998    637.919983
# 1996-02-27    637.919983    640.570007    628.450012    631.099976
# 1996-02-28    631.099976    638.789978    629.900024    631.440002
# ...                  ...           ...           ...           ...
# 2024-01-26  17432.869141  17514.759766  17395.539062  17421.009766
# 2024-01-29  17438.029297  17603.949219  17414.619141  17596.269531
# 2024-01-30  17556.490234  17578.460938  17443.769531  17476.710938
# 2024-01-31  17269.980469  17375.320312  17128.740234  17137.240234
# 2024-02-01  17216.990234  17356.759766  17175.830078  17344.710938
#
#                Adj Close      Volume      Change  Direction          MA10  \
# Date
# ...

# %%
plt = plot_chart_line(
    data=data['Close'],
    label='Nasdaq Close Price',
    title='Nasdaq Daily Close Price'
)

# %% [markdown]
# ---

# %% [markdown]
# ## Dow Jones Industrial Average

# %%
data = get_data(DJI_TICKER)
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 1996-02-22   5516.330078   5613.879883   5516.330078   5608.459961
# 1996-02-23   5608.500000   5659.399902   5560.410156   5630.490234
# 1996-02-26   5629.100098   5629.770020   5559.680176   5565.100098
# 1996-02-27   5564.000000   5564.020020   5509.100098   5549.209961
# 1996-02-28   5547.799805   5593.279785   5495.740234   5506.209961
# ...                  ...           ...           ...           ...
# 2024-01-26  38006.679688  38215.308594  37997.769531  38109.429688
# 2024-01-29  38115.828125  38343.929688  38061.171875  38333.449219
# 2024-01-30  38298.230469  38497.390625  38257.800781  38467.308594
# 2024-01-31  38426.781250  38588.859375  38139.660156  38150.300781
# 2024-02-01  38175.339844  38522.500000  38106.839844  38519.839844
#
#                Adj Close     Volume      Change  Direction          MA10  \
# Date
# 1996-02-22   5608.459961   41570000   92.129883          1   5549.964990
# ...

# %%
plt = plot_chart_line(
    data=data['Close'],
    label='Dow Jones Close Price',
    title='Dow Jones Daily Close Price'
)

# %% [markdown]
# ---

# %% [markdown]
# ## Gold

# %%
gold_data = get_data(GOLD_TICKER)
gold_data
# Out:
# f:\DR\Stock-Market-Prediction\venv\lib\site-packages\yfinance\utils.py:775: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File f:\DR\Stock-Market-Prediction\venv\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
plt = plot_chart_line(
    data=gold_data['Close'],
    label='Gold Close Price',
    title='Gold Daily Close Price'
)
